# %%
# %% [markdown]
# # IFCManager - Ejemplo de Uso Completo
# 
# Este notebook demuestra las funcionalidades principales del módulo IFCManager para análisis de archivos IFC.

# %% [markdown]
# ## 1. Importación de Librerías

# %%
import sys
import os
import logging
import pandas as pd
from pathlib import Path

# Agregar el directorio src al path
sys.path.append('src')

# Importar directamente desde el paquete principal
from ifc_manager import IFCManager, IFCParser, ModelVisualizer

# Configurar logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %% [markdown]
# ## 2. Inicialización del IFCManager

# %%
# Ruta al archivo IFC (ajustar según tu archivo)
ifc_file_path = "sample_models/Edificio_modelo.ifc"  # Cambiar por tu archivo IFC

# Inicializar el manager
manager = IFCManager()

# %% [markdown]
# ## 3. Carga y Análisis del Archivo IFC

# %%
try:
    # Cargar archivo IFC
    success = manager.load_ifc(ifc_file_path)
    
    if success:
        print("✅ Archivo IFC cargado exitosamente")
        
        # Extraer elementos estructurales
        elements = manager.extract_structural_elements()
        print(f"📊 Elementos estructurales extraídos: {len(elements)}")
        
    else:
        print("❌ Error al cargar el archivo IFC")
        # Crear datos de ejemplo para demostración
        print("🔧 Creando datos de ejemplo para demostración...")
        elements = create_sample_data()
        manager.structural_elements = elements
        
except Exception as e:
    print(f"❌ Error: {e}")
    print("🔧 Creando datos de ejemplo para demostración...")
    elements = create_sample_data()
    manager.structural_elements = elements

# %% [markdown]
# ## 4. Función para Crear Datos de Ejemplo

# %%
def create_sample_data():
    """Crea datos de ejemplo cuando no hay archivo IFC disponible."""
    return {
        'beam-001': {
            'id': 'beam-001',
            'name': 'Viga Principal',
            'type': 'IfcBeam',
            'geometry': {
                'type': 'line',
                'start': [0, 0, 3],
                'end': [6, 0, 3],
                'vertices': [[0,0,3], [6,0,3], [6,0.3,3], [0,0.3,3]],
                'triangles': [[0,1,2], [0,2,3]]
            },
            'material': {
                'Concreto': {
                    'name': 'Concreto',
                    'type': 'material',
                    'properties': {'fc': 25, 'density': 2400}
                }
            },
            'profile': {
                'shape': 'rectangular',
                'height': 0.4,
                'width': 0.3
            },
            'properties': {}
        },
        'column-001': {
            'id': 'column-001',
            'name': 'Columna C1',
            'type': 'IfcColumn',
            'geometry': {
                'type': 'line',
                'start': [0, 0, 0],
                'end': [0, 0, 3],
                'vertices': [[0,0,0], [0,0,3], [0.3,0,3], [0.3,0,0]],
                'triangles': [[0,1,2], [0,2,3]]
            },
            'material': {
                'Concreto': {
                    'name': 'Concreto',
                    'type': 'material',
                    'properties': {'fc': 25, 'density': 2400}
                }
            },
            'profile': {
                'shape': 'rectangular',
                'height': 0.3,
                'width': 0.3
            },
            'properties': {}
        },
        'slab-001': {
            'id': 'slab-001',
            'name': 'Losa Nivel 1',
            'type': 'IfcSlab',
            'geometry': {
                'type': 'mesh',
                'vertices': [[0,0,3], [6,0,3], [6,4,3], [0,4,3]],
                'triangles': [[0,1,2], [0,2,3]]
            },
            'material': {
                'Concreto': {
                    'name': 'Concreto',
                    'type': 'material',
                    'properties': {'fc': 25, 'density': 2400}
                }
            },
            'profile': None,
            'properties': {'thickness': 0.15}
        }
    }

# %% [markdown]
# ## 5. Análisis de Elementos por Tipo

# %%
# Contar elementos por tipo
element_types = {}
for elem_id, elem_data in manager.structural_elements.items():
    elem_type = elem_data['type']
    element_types[elem_type] = element_types.get(elem_type, 0) + 1

print("📈 Resumen de elementos por tipo:")
for elem_type, count in element_types.items():
    print(f"  • {elem_type}: {count}")

# %% [markdown]
# ## 6. Análisis de Materiales

# %%
# Extraer información de materiales
materials_summary = {}
for elem_id, elem_data in manager.structural_elements.items():
    if elem_data.get('material'):
        for mat_name, mat_data in elem_data['material'].items():
            if mat_name not in materials_summary:
                materials_summary[mat_name] = {
                    'count': 0,
                    'elements': [],
                    'properties': mat_data.get('properties', {})
                }
            materials_summary[mat_name]['count'] += 1
            materials_summary[mat_name]['elements'].append(elem_data['name'])

print("🏗️ Resumen de materiales:")
for mat_name, mat_info in materials_summary.items():
    print(f"  • {mat_name}: {mat_info['count']} elementos")
    if mat_info['properties']:
        print(f"    Propiedades: {list(mat_info['properties'].keys())}")

# %% [markdown]
# ## 7. Crear DataFrame para Análisis

# %%
# Convertir elementos a DataFrame para análisis
elements_data = []
for elem_id, elem_data in manager.structural_elements.items():
    row = {
        'ID': elem_data['id'],
        'Name': elem_data['name'],
        'Type': elem_data['type'],
        'Has_Geometry': 'geometry' in elem_data,
        'Has_Material': 'material' in elem_data,
        'Has_Profile': 'profile' in elem_data and elem_data['profile'] is not None
    }
    
    # Agregar información de perfil si existe
    if elem_data.get('profile'):
        profile = elem_data['profile']
        row['Profile_Shape'] = profile.get('shape', 'N/A')
        row['Profile_Height'] = profile.get('height', 0)
        row['Profile_Width'] = profile.get('width', 0)
    
    # Agregar material principal
    if elem_data.get('material'):
        materials = list(elem_data['material'].keys())
        row['Primary_Material'] = materials[0] if materials else 'N/A'
    
    elements_data.append(row)

df_elements = pd.DataFrame(elements_data)
print("📊 DataFrame de elementos estructurales:")
print(df_elements.to_string(index=False))

# %% [markdown]
# ## 8. Funciones de Consulta

# %%
# Demostrar funciones de consulta del parser
if hasattr(manager, 'parser') and manager.parser:
    parser = manager.parser
    
    # Buscar elementos por tipo
    beams = parser.get_elements_by_type('IfcBeam')
    columns = parser.get_elements_by_type('IfcColumn')
    slabs = parser.get_elements_by_type('IfcSlab')
    
    print(f"🔍 Consultas específicas:")
    print(f"  • Vigas encontradas: {len(beams)}")
    print(f"  • Columnas encontradas: {len(columns)}")
    print(f"  • Losas encontradas: {len(slabs)}")
    
    # Mostrar detalles de un elemento específico
    if beams:
        beam_id = list(beams.keys())[0]
        beam_data = parser.get_structural_element(beam_id)
        print(f"\n📋 Detalles de viga {beam_id}:")
        print(f"  • Nombre: {beam_data.get('name', 'Sin nombre')}")
        print(f"  • Tipo: {beam_data.get('type')}")
        if beam_data.get('profile'):
            profile = beam_data['profile']
            print(f"  • Perfil: {profile.get('shape')} - {profile.get('height')}x{profile.get('width')}")

# %% [markdown]
# ## 9. Visualización 3D

# %%
try:
    # Crear visualización
    fig = manager.visualize_model()
    
    # Mostrar la figura
    fig.show()
    print("✅ Visualización 3D generada exitosamente")
    print("💡 La visualización se abrirá en una nueva ventana del navegador")
    
except Exception as e:
    print(f"❌ Error en visualización: {e}")
    print("💡 Asegúrate de tener Plotly instalado: pip install plotly")

# %% [markdown]
# ## 10. Estadísticas Finales

# %%
# Generar estadísticas finales
total_elements = len(manager.structural_elements)
elements_with_geometry = sum(1 for elem in manager.structural_elements.values() 
                            if 'geometry' in elem)
elements_with_material = sum(1 for elem in manager.structural_elements.values() 
                           if 'material' in elem)

print("📈 Estadísticas finales del análisis:")
print(f"  • Total de elementos: {total_elements}")
print(f"  • Elementos con geometría: {elements_with_geometry}")
print(f"  • Elementos con material: {elements_with_material}")
print(f"  • Tipos de elementos únicos: {len(element_types)}")
print(f"  • Materiales únicos: {len(materials_summary)}")

# Calcular porcentajes
if total_elements > 0:
    geom_percent = (elements_with_geometry / total_elements) * 100
    mat_percent = (elements_with_material / total_elements) * 100
    print(f"  • Completitud de geometría: {geom_percent:.1f}%")
    print(f"  • Completitud de materiales: {mat_percent:.1f}%")

print("\n🎉 Análisis completado exitosamente!")

# %% [markdown]
# ## Conclusiones
# 
# Este ejemplo demuestra las capacidades principales del módulo IFCManager:
# 
# 1. **Carga de archivos IFC** - Lectura y validación de archivos
# 2. **Extracción de elementos** - Identificación de elementos estructurales
# 3. **Análisis de propiedades** - Materiales, perfiles y geometría
# 4. **Consultas específicas** - Filtrado por tipo y búsquedas
# 5. **Visualización 3D** - Representación gráfica del modelo
# 6. **Análisis estadístico** - Resúmenes y métricas del modelo
# 
# El módulo proporciona una interfaz sencilla para trabajar con modelos BIM y extraer información relevante para análisis estructural.
# Out:
# INFO: Loading IFC file: sample_models/Edificio_modelo.ifc
# INFO: IFC file loaded successfully with 818 products
# INFO: Extracting structural elements...
# INFO: Found 456 elements of type IfcBeam
# ✅ Archivo IFC cargado exitosamente
# INFO: Found 255 elements of type IfcColumn
# INFO: Found 17 elements of type IfcSlab
# INFO: Found 53 elements of type IfcWall
# INFO: Found 0 elements of type IfcFooting
# INFO: Found 0 elements of type IfcPile
# INFO: Found 0 elements of type IfcMember
# INFO: Extracted 781 structural elements in total
# INFO: Extracting geometry for structural elements...
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rK: Failed to process shape. Product: #2529=IfcBeam('2goMSLe097heFCxc4gJ0rK',#18,'Hormigón-Viga rectangular:300 x 600mm:385765',$,'Hormigón-Viga rectangular:300 x 600mm',#2528,#2525,'385765',.BEAM.), representation: #2524=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2523))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rN: Failed to process shape. Product: #2556=IfcBeam('2goMSLe097heFCxc4gJ0rN',#18,'Hormigón-Viga rectangular:300 x 600mm:385766',$,'Hormigón-Viga rectangular:300 x 600mm',#2555,#2552,'385766',.BEAM.), representation: #2551=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2550))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rM: Failed to process shape. Product: #2583=IfcBeam('2goMSLe097heFCxc4gJ0rM',#18,'Hormigón-Viga rectangular:300 x 600mm:385767',$,'Hormigón-Viga rectangular:300 x 600mm',#2582,#2579,'385767',.BEAM.), representation: #2578=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2577))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rP: Failed to process shape. Product: #2611=IfcBeam('2goMSLe097heFCxc4gJ0rP',#18,'Hormigón-Viga rectangular:300 x 600mm:385768',$,'Hormigón-Viga rectangular:300 x 600mm',#2610,#2607,'385768',.BEAM.), representation: #2606=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2605))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rO: Failed to process shape. Product: #2638=IfcBeam('2goMSLe097heFCxc4gJ0rO',#18,'Hormigón-Viga rectangular:300 x 600mm:385769',$,'Hormigón-Viga rectangular:300 x 600mm',#2637,#2634,'385769',.BEAM.), representation: #2633=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2632))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rR: Failed to process shape. Product: #2665=IfcBeam('2goMSLe097heFCxc4gJ0rR',#18,'Hormigón-Viga rectangular:300 x 600mm:385770',$,'Hormigón-Viga rectangular:300 x 600mm',#2664,#2661,'385770',.BEAM.), representation: #2660=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2659))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rQ: Failed to process shape. Product: #2692=IfcBeam('2goMSLe097heFCxc4gJ0rQ',#18,'Hormigón-Viga rectangular:300 x 600mm:385771',$,'Hormigón-Viga rectangular:300 x 600mm',#2691,#2688,'385771',.BEAM.), representation: #2687=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2686))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rT: Failed to process shape. Product: #2720=IfcBeam('2goMSLe097heFCxc4gJ0rT',#18,'Hormigón-Viga rectangular:300 x 600mm:385772',$,'Hormigón-Viga rectangular:300 x 600mm',#2719,#2716,'385772',.BEAM.), representation: #2715=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2714))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rS: Failed to process shape. Product: #2748=IfcBeam('2goMSLe097heFCxc4gJ0rS',#18,'Hormigón-Viga rectangular:300 x 600mm:385773',$,'Hormigón-Viga rectangular:300 x 600mm',#2747,#2744,'385773',.BEAM.), representation: #2743=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2742))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rU: Failed to process shape. Product: #2809=IfcBeam('2goMSLe097heFCxc4gJ0rU',#18,'Hormigón-Viga rectangular:300 x 600mm:385775',$,'Hormigón-Viga rectangular:300 x 600mm',#2808,#2805,'385775',.BEAM.), representation: #2804=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2803))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0r1: Failed to process shape. Product: #2836=IfcBeam('2goMSLe097heFCxc4gJ0r1',#18,'Hormigón-Viga rectangular:300 x 600mm:385776',$,'Hormigón-Viga rectangular:300 x 600mm',#2835,#2832,'385776',.BEAM.), representation: #2831=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#2830))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0r7: Failed to process shape. Product: #3034=IfcBeam('2goMSLe097heFCxc4gJ0r7',#18,'Hormigón-Viga rectangular:300 x 600mm:385782',$,'Hormigón-Viga rectangular:300 x 600mm',#3033,#3030,'385782',.BEAM.), representation: #3029=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3028))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0r9: Failed to process shape. Product: #3061=IfcBeam('2goMSLe097heFCxc4gJ0r9',#18,'Hormigón-Viga rectangular:300 x 600mm:385784',$,'Hormigón-Viga rectangular:300 x 600mm',#3060,#3057,'385784',.BEAM.), representation: #3056=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3055))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0r8: Failed to process shape. Product: #3088=IfcBeam('2goMSLe097heFCxc4gJ0r8',#18,'Hormigón-Viga rectangular:300 x 600mm:385785',$,'Hormigón-Viga rectangular:300 x 600mm',#3087,#3084,'385785',.BEAM.), representation: #3083=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3082))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rB: Failed to process shape. Product: #3115=IfcBeam('2goMSLe097heFCxc4gJ0rB',#18,'Hormigón-Viga rectangular:300 x 600mm:385786',$,'Hormigón-Viga rectangular:300 x 600mm',#3114,#3111,'385786',.BEAM.), representation: #3110=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3109))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rA: Failed to process shape. Product: #3142=IfcBeam('2goMSLe097heFCxc4gJ0rA',#18,'Hormigón-Viga rectangular:300 x 600mm:385787',$,'Hormigón-Viga rectangular:300 x 600mm',#3141,#3138,'385787',.BEAM.), representation: #3137=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3136))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rD: Failed to process shape. Product: #3169=IfcBeam('2goMSLe097heFCxc4gJ0rD',#18,'Hormigón-Viga rectangular:300 x 600mm:385788',$,'Hormigón-Viga rectangular:300 x 600mm',#3168,#3165,'385788',.BEAM.), representation: #3164=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3163))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rC: Failed to process shape. Product: #3196=IfcBeam('2goMSLe097heFCxc4gJ0rC',#18,'Hormigón-Viga rectangular:300 x 600mm:385789',$,'Hormigón-Viga rectangular:300 x 600mm',#3195,#3192,'385789',.BEAM.), representation: #3191=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3190))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rF: Failed to process shape. Product: #3223=IfcBeam('2goMSLe097heFCxc4gJ0rF',#18,'Hormigón-Viga rectangular:300 x 600mm:385790',$,'Hormigón-Viga rectangular:300 x 600mm',#3222,#3219,'385790',.BEAM.), representation: #3218=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3217))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0rE: Failed to process shape. Product: #3250=IfcBeam('2goMSLe097heFCxc4gJ0rE',#18,'Hormigón-Viga rectangular:300 x 600mm:385791',$,'Hormigón-Viga rectangular:300 x 600mm',#3249,#3246,'385791',.BEAM.), representation: #3245=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3244))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0on: Failed to process shape. Product: #3277=IfcBeam('2goMSLe097heFCxc4gJ0on',#18,'Hormigón-Viga rectangular:300 x 600mm:385792',$,'Hormigón-Viga rectangular:300 x 600mm',#3276,#3273,'385792',.BEAM.), representation: #3272=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3271))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0om: Failed to process shape. Product: #3304=IfcBeam('2goMSLe097heFCxc4gJ0om',#18,'Hormigón-Viga rectangular:300 x 600mm:385793',$,'Hormigón-Viga rectangular:300 x 600mm',#3303,#3300,'385793',.BEAM.), representation: #3299=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3298))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0op: Failed to process shape. Product: #3331=IfcBeam('2goMSLe097heFCxc4gJ0op',#18,'Hormigón-Viga rectangular:300 x 600mm:385794',$,'Hormigón-Viga rectangular:300 x 600mm',#3330,#3327,'385794',.BEAM.), representation: #3326=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3325))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0oo: Failed to process shape. Product: #3358=IfcBeam('2goMSLe097heFCxc4gJ0oo',#18,'Hormigón-Viga rectangular:300 x 600mm:385795',$,'Hormigón-Viga rectangular:300 x 600mm',#3357,#3354,'385795',.BEAM.), representation: #3353=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3352))
# WARNING: Error processing geometry for element 2goMSLe097heFCxc4gJ0or: Failed to process shape. Product: #3385=IfcBeam('2goMSLe097heFCxc4gJ0or',#18,'Hormigón-Viga rectangular:300 x 600mm:385796',$,'Hormigón-Viga rectangular:300 x 600mm',#3384,#3381,'385796',.BEAM.), representation: #3380=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#3379))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$bPj: Failed to process shape. Product: #33659=IfcBeam('3L9_0igGrFggt_nGcW$bPj',#18,'Hormigón-Viga rectangular:300 x 600mm:396267',$,'Hormigón-Viga rectangular:300 x 600mm',#33658,#33655,'396267',.BEAM.), representation: #33654=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#33653))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$bPt: Failed to process shape. Product: #33750=IfcBeam('3L9_0igGrFggt_nGcW$bPt',#18,'Hormigón-Viga rectangular:300 x 600mm:396273',$,'Hormigón-Viga rectangular:300 x 600mm',#33749,#33746,'396273',.BEAM.), representation: #33745=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#33744))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$bPm: Failed to process shape. Product: #33841=IfcBeam('3L9_0igGrFggt_nGcW$bPm',#18,'Hormigón-Viga rectangular:300 x 600mm:396278',$,'Hormigón-Viga rectangular:300 x 600mm',#33840,#33837,'396278',.BEAM.), representation: #33836=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#33835))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$bPz: Failed to process shape. Product: #33932=IfcBeam('3L9_0igGrFggt_nGcW$bPz',#18,'Hormigón-Viga rectangular:300 x 600mm:396283',$,'Hormigón-Viga rectangular:300 x 600mm',#33931,#33928,'396283',.BEAM.), representation: #33927=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#33926))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b66: Failed to process shape. Product: #34023=IfcBeam('3L9_0igGrFggt_nGcW$b66',#18,'Hormigón-Viga rectangular:300 x 600mm:396288',$,'Hormigón-Viga rectangular:300 x 600mm',#34022,#34019,'396288',.BEAM.), representation: #34018=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34017))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b63: Failed to process shape. Product: #34114=IfcBeam('3L9_0igGrFggt_nGcW$b63',#18,'Hormigón-Viga rectangular:300 x 600mm:396293',$,'Hormigón-Viga rectangular:300 x 600mm',#34113,#34110,'396293',.BEAM.), representation: #34109=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34108))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6C: Failed to process shape. Product: #34205=IfcBeam('3L9_0igGrFggt_nGcW$b6C',#18,'Hormigón-Viga rectangular:300 x 600mm:396298',$,'Hormigón-Viga rectangular:300 x 600mm',#34204,#34201,'396298',.BEAM.), representation: #34200=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34199))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b69: Failed to process shape. Product: #34296=IfcBeam('3L9_0igGrFggt_nGcW$b69',#18,'Hormigón-Viga rectangular:300 x 600mm:396303',$,'Hormigón-Viga rectangular:300 x 600mm',#34295,#34292,'396303',.BEAM.), representation: #34291=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34290))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6I: Failed to process shape. Product: #34387=IfcBeam('3L9_0igGrFggt_nGcW$b6I',#18,'Hormigón-Viga rectangular:300 x 600mm:396308',$,'Hormigón-Viga rectangular:300 x 600mm',#34386,#34383,'396308',.BEAM.), representation: #34382=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34381))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6V: Failed to process shape. Product: #34478=IfcBeam('3L9_0igGrFggt_nGcW$b6V',#18,'Hormigón-Viga rectangular:300 x 600mm:396313',$,'Hormigón-Viga rectangular:300 x 600mm',#34477,#34474,'396313',.BEAM.), representation: #34473=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34472))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6O: Failed to process shape. Product: #34569=IfcBeam('3L9_0igGrFggt_nGcW$b6O',#18,'Hormigón-Viga rectangular:300 x 600mm:396318',$,'Hormigón-Viga rectangular:300 x 600mm',#34568,#34565,'396318',.BEAM.), representation: #34564=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34563))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6b: Failed to process shape. Product: #34660=IfcBeam('3L9_0igGrFggt_nGcW$b6b',#18,'Hormigón-Viga rectangular:300 x 600mm:396323',$,'Hormigón-Viga rectangular:300 x 600mm',#34659,#34656,'396323',.BEAM.), representation: #34655=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34654))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6k: Failed to process shape. Product: #34751=IfcBeam('3L9_0igGrFggt_nGcW$b6k',#18,'Hormigón-Viga rectangular:300 x 600mm:396328',$,'Hormigón-Viga rectangular:300 x 600mm',#34750,#34747,'396328',.BEAM.), representation: #34746=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34745))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6h: Failed to process shape. Product: #34842=IfcBeam('3L9_0igGrFggt_nGcW$b6h',#18,'Hormigón-Viga rectangular:300 x 600mm:396333',$,'Hormigón-Viga rectangular:300 x 600mm',#34841,#34838,'396333',.BEAM.), representation: #34837=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34836))
# WARNING: Error processing geometry for element 3L9_0igGrFggt_nGcW$b6q: Failed to process shape. Product: #34933=IfcBeam('3L9_0igGrFggt_nGcW$b6q',#18,'Hormigón-Viga rectangular:300 x 600mm:396338',$,'Hormigón-Viga rectangular:300 x 600mm',#34932,#34929,'396338',.BEAM.), representation: #34928=IfcShapeRepresentation(#23,'Axis','MappedRepresentation',(#34927))
# INFO: Geometry extraction completed
# ❌ Error: 'NoneType' object is not subscriptable
# 🔧 Creando datos de ejemplo para demostración...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 47
#      46 # Extraer elementos estructurales
# ---> 47 elements = manager.extract_structural_elements()
#      48 print(f"📊 Elementos estructurales extraídos: {len(elements)}")
#
# File ~\Desktop\CODIGO\IFC_Manager\src\ifc_manager\core\__init__.py:53, in IFCManager.extract_structural_elements(self)
#      52 # NUEVO: Calcular propiedades automáticamente
# ---> 53 self.parser.calculate_element_properties()
#      55 return self.structural_elements
#
# File ~\Desktop\CODIGO\IFC_Manager\src\ifc_manager\core\ifc_parser.py:457, in IFCParser.calculate_element_properties(self)
#     456 # Elementos tipo malla (slabs, walls)
# --> 457 if geom['type'] == 'mesh':  # CORREGIDO: era 'esh'
#     458     vertices = np.array(geom['vertices'])
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 60
#      58     print(f"❌ Error: {e}")
#      59     print("🔧 Creando datos de ejemplo para demostración...")
# ---> 60     elements = create_sample_data()
#      61     manager.structural_elements = elements
#      63 # %% [markdown]
#      64 # ## 4. Función para Crear Datos de Ejemplo
#      65
#      66 # %%
#
# NameError: name 'create_sample_data' is not defined
